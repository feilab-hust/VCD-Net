# %% [markdown]
# #### This notebook navigates you through the pipeline of VCD-LFM.
#
# There are three notebooks to go through in total:
# 1. [datapre](./datapre/datapre.ipynb) for dataset generation
# 2. [train_demo](./vcdnet/train_demo.ipynb) for model training
# 3. [predict_demo](./vcdnet/predict_demo.ipynb) for model application
#
# Start demo by clicking on [datapre](../datapre/datapre.ipynb).
